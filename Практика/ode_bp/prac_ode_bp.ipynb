# %%
# %matplotlib inline
import pylab
import numpy as np
from matplotlib import pyplot as plt
import matplotlib
from scipy import integrate

# %% [markdown]
# **Задача 1**
# Получите формулу для главного члена ошибки в конечно-разностной формуле:
# $$
# u''(x) \approx \frac{u(x+h) -2 u(x) + u(x - h)}{h^2}
# $$
# и выведите формулу 4-го порядка аппроксимации для случая, когда $u^{(4)}(x)$ -- известно (*нужно вычесть из КР формулы главный член ошибки*)
#
#
# **Задача 2**
# Для решения краевой задачи
# $$
# u''(x) = f(x) \; u(0) = a, u(1) = b
# $$
# на равномерной сетке используется КР формула 4-го порядка из предыдущей задачи.
# Выпишите матрицу и правую часть линейной системы уравнений относительно неизвестных значений в узлах сетки. Подумайте, как можно вычислить $u^{(4)}(x)$?
#
# **Задача 3**
# Напишите функцию, реализующую метод из предыдущей задачи. Функция должна принимать на вход количество узлов, ссылку на функцию $f$, ссылку на $f''$ и граничные значения. Для решения системы используйте функцию ```scipy.linalg.solve_banded```
#
# Для тестовой задачи с точным решением постройте график зависимости ошибки от шага сетки в логарифмической шкале. Убедитесь, что получился 4-й порядок аппроксимации.

# %% [markdown]
# **Задача 4** (2 балла)
# Напишите функцию для решения краевой задачи  тем же методом на произвольной неравномерной сетке. Сравните точность 2-х решений на равномерной и неравномерной сетках с одинаковым количеством узлов для функции $u = 1/(1 + 10 x)^2$ (*сгущать узлы нужно там, где функция быстро меняется*)
