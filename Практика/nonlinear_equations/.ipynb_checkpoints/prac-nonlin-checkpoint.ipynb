# %%
# %matplotlib inline
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# **Задача 1**
# Пусть $F \in C^1(\mathbb{R})$, $z$ - единственная неподвижная точка $F$: $z = F(z)$. Докажите:
# 1. Если $\vert F'(z) \vert < 1$, то $\exists \delta > 0$: метод простых итераций сходится $\forall x_0 \in [z-\delta, z + \delta]$
# 2. Если $F'(z) > 1$, то метод простых итераций расходится для любого $x_0 \ne z$
#
# **Задача 2**
# * Предложите сходящийся МПИ для вычисления меньшего положительного корня уравнения $e^x - 5x^2 = 0$.
# * Выведите оценку числа итераций для достижения заданной точности, посчитайте число итераций для $tol = 10^{-10}$
# * Напишите программу для вычисления корня, сравните ошибку с теоретической оценкой (за точное значение корня возьмите численное решение после большого числа итераций)

# %%
# YOUR CODE HERE

# %% [markdown]
# **Задача 3**
# * Напишите формулу шага метода Ньютона вычисления меньшего положительного корня уравнения $e^x - 5x^2 = 0$.
# * Выведите оценку числа итераций для достижения заданной точности, посчитайте число итераций для $tol = 10^{-10}$
# * Напишите программу для вычисления корня, сравните ошибку с теоретической оценкой (за точное значение корня возьмите численное решение после большого числа итераций)

# %%
# YOUR CODE HERE

# %% [markdown]
# **Задача 4**
# 1. Выведите формулы метода Ньютона для решения уравнения $f(x) = x^{-1} - a = 0$.
# 2.  Оцените, сколько итераций метода Ньютона требуется, чтобы найти обратное к числу $a$ с нужной точностью в IEEE арифметиках одинарной и двойной точностей (число $a$ предварительно нормируется, можно считать, что $a \in [0.5, 1]$)
# 3. С помощью теоремы об альтернансе найдите линейное приближение к функции $x^{-1}$ на отрезке $[0.5,1]$, которое минимизует *относительную ошибку*. Оцените число итераций в методе Ньютона, если начальное вычисляется по этому линейному приближению.
# 4. Напишите программу для метода Ньютона, сравните два способа выбора начального приближения. Влияет ли это на число итераций?
#
# Такой метод используется для деления  в компьютерах:
# [Fast_division_methods](https://en.wikipedia.org/wiki/Division_algorithm#Fast_division_methods)

# %% [markdown]
# **Задача 5**  (2 балла)
# Напишите программу для *метода парабол*: итерационного метода, в котором по последним 3-м приближениям строится многочлен 2-й степени, и 1 из его корней берётся в качестве следующего приближения.
#
# Примените метод для уравнения с точным решением, сравните скорость сходимости с методом Ньютона.
