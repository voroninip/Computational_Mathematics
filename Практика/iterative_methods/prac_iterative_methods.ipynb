# %% [markdown]
# **Задача 1**
# При вычислениях на компьютере на каждой итерации метода $x^{k+1} = S x^{k} + b$ вносятся ошибки:
# $$
# x_M^{k+1} = S x_M^{k} + b + \delta^k
# $$
# Оцените $\Vert x_M^N - x^N \Vert$, если известно, что $\Vert \delta^k \Vert \le \delta$

# %% [markdown]
# **Задача 2**
# Решается действительная система:
# $$
# A x = b, \; A = A^T > 0, \lambda_{min}(A)  = 1, \; \lambda_{max}(A) = 500
# $$
# Также про точное решение известно, что $||x||_2 \le 2$.
#
# Оцените число итераций для достижения в 2-норме точности $\epsilon = 10^{-6}$ с помощью итерационного метода Ричардсона с оптимальным параметром.

# %% [markdown]
# **Задача 3**
# Выведите выражение для параметра $\tau$ в методе минимальных невязок ($A = A^T >0$):
# $$
# x^{k+1} = x^k - \tau (A x^{k} - b), \tau = argmin_\tau \Vert A x^{k+1} - b \Vert_2
# $$

# %% [markdown]
# **Задача 4**
# $A$ имеет строчное диагональное преобладание. Докажите, что метод Зейделя для этой матрицы сходится. Оцените скорость сходимости в $\Vert \cdot\Vert_\infty$.

# %% [markdown]
# **Задача 5**  (1 балл)
# Напишите функцию для *метода верхней релаксации* (successive over relaxation)
# $$
# (D + \omega L) x^{k+1}  = \omega b - (\omega U + (\omega - 1) D) x^k
# $$
# При $\omega = 1$ этот метод переходит в метод Зейделя.
#
# При написании программы можно использовать готовые функции для обращения матриц и матрично-векторного умножения.
#
# Создайте матрицу $A = A^T > 0$. Для значений $\omega \in (0,2)$ с шагом 0.1 сделайте одинаковое (большое) число итераций метода, сохраните значения нормы невязки на каждой итерации.
#
# Постройте на одном рисунке зависимости логарифма невязки от номера итерации. Определите примерное значение оптимального параметра.
#
# (**Еще 1 балл**)
# Измерьте время работы вашей функции на большой матрице ($n = 10^3 - 10^4$). Сравните с временем работы прямого метода из ```numpy```.
#
# Перепишите вашу функцию через циклы без использования готовых функций, для ускорения циклов примените ```@jit``` декоратор из ```numba```. Убедитесь, что функция стала работать значительно быстрее.
